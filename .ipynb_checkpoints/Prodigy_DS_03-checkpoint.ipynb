# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv("bank.csv", delimiter=";")

# %%
df.head()
# Out:
#    age        job  marital    education  default housing loan    contact  \
# 0   56  housemaid  married     basic.4y       no      no   no  telephone
# 1   57   services  married  high.school  unknown      no   no  telephone
# 2   37   services  married  high.school       no     yes   no  telephone
# 3   40     admin.  married     basic.6y       no      no   no  telephone
# 4   56   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...         1    999         0  nonexistent          1.1
# 1   may         mon  ...         1    999         0  nonexistent          1.1
# 2   may         mon  ...         1    999         0  nonexistent          1.1
# 3   may         mon  ...         1    999         0  nonexistent          1.1
# 4   may         mon  ...         1    999         0  nonexistent          1.1
#
# ...

# %%
df.rename(columns={'y':'deposit'},inplace=True)

# %%
df.head()
# Out:
#    age        job  marital    education  default housing loan    contact  \
# 0   56  housemaid  married     basic.4y       no      no   no  telephone
# 1   57   services  married  high.school  unknown      no   no  telephone
# 2   37   services  married  high.school       no     yes   no  telephone
# 3   40     admin.  married     basic.6y       no      no   no  telephone
# 4   56   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...         1    999         0  nonexistent          1.1
# 1   may         mon  ...         1    999         0  nonexistent          1.1
# 2   may         mon  ...         1    999         0  nonexistent          1.1
# 3   may         mon  ...         1    999         0  nonexistent          1.1
# 4   may         mon  ...         1    999         0  nonexistent          1.1
#
# ...

# %%
df.shape
# Out:
# (41188, 21)

# %% [markdown]
# # Data Preprocessing

# %%
df.isna().sum()
# Out:
# age               0
# job               0
# marital           0
# education         0
# default           0
# housing           0
# loan              0
# contact           0
# month             0
# day_of_week       0
# duration          0
# campaign          0
# pdays             0
# previous          0
# poutcome          0
# emp.var.rate      0
# cons.price.idx    0
# cons.conf.idx     0
# euribor3m         0
# nr.employed       0
# deposit           0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41188 entries, 0 to 41187
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             41188 non-null  int64
#  1   job             41188 non-null  object
#  2   marital         41188 non-null  object
#  3   education       41188 non-null  object
#  4   default         41188 non-null  object
#  5   housing         41188 non-null  object
#  6   loan            41188 non-null  object
#  7   contact         41188 non-null  object
#  8   month           41188 non-null  object
#  9   day_of_week     41188 non-null  object
#  10  duration        41188 non-null  int64
#  11  campaign        41188 non-null  int64
#  12  pdays           41188 non-null  int64
#  13  previous        41188 non-null  int64
#  14  poutcome        41188 non-null  object
#  15  emp.var.rate    41188 non-null  float64
#  16  cons.price.idx  41188 non-null  float64
# ...

# %%
df.duplicated().sum()
# Out:
# 12

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (41176, 21)

# %%
cat_cols=df.select_dtypes(include='object').columns.to_list()
print(cat_cols)

num_col=df.select_dtypes(exclude='object').columns.to_list()
print("\n\n",num_col)
# Out:
# ['job', 'marital', 'education', 'default', 'housing', 'loan', 'contact', 'month', 'day_of_week', 'poutcome', 'deposit']
#
#
#  ['age', 'duration', 'campaign', 'pdays', 'previous', 'emp.var.rate', 'cons.price.idx', 'cons.conf.idx', 'euribor3m', 'nr.employed']

# %%
df.describe()
# Out:
#                age      duration      campaign         pdays      previous  \
# count  41176.00000  41176.000000  41176.000000  41176.000000  41176.000000
# mean      40.02380    258.315815      2.567879    962.464810      0.173013
# std       10.42068    259.305321      2.770318    186.937102      0.494964
# min       17.00000      0.000000      1.000000      0.000000      0.000000
# 25%       32.00000    102.000000      1.000000    999.000000      0.000000
# 50%       38.00000    180.000000      2.000000    999.000000      0.000000
# 75%       47.00000    319.000000      3.000000    999.000000      0.000000
# max       98.00000   4918.000000     56.000000    999.000000      7.000000
#
#        emp.var.rate  cons.price.idx  cons.conf.idx     euribor3m   nr.employed
# count  41176.000000    41176.000000   41176.000000  41176.000000  41176.000000
# mean       0.081922       93.575720     -40.502863      3.621293   5167.034870
# ...

# %%
df.describe(include='object')
# Out:
#            job  marital          education default housing   loan   contact  \
# count    41176    41176              41176   41176   41176  41176     41176
# unique      12        4                  8       3       3      3         2
# top     admin.  married  university.degree      no     yes     no  cellular
# freq     10419    24921              12164   32577   21571  33938     26135
#
#         month day_of_week     poutcome deposit
# count   41176       41176        41176   41176
# unique     10           5            3       2
# top       may         thu  nonexistent      no
# freq    13767        8618        35551   36537

# %%
df[num_col].hist(figsize=(30,30))
plt.show()

# %%
for col in cat_cols:
    plt.figure(figsize=(6,6))
    sns.countplot(x=col,data=df)
    plt.title("Bar plot of {}".format(col))
    plt.xlabel(col)
    plt.ylabel("Count")
    plt.xticks(rotation=90)
    plt.show()

# %%
df.plot(kind='box',subplots=True,layout=(2,5), figsize=(20,10))
plt.show()

# %%
columns=df[['age','duration','campaign']]
Q1=columns.quantile(0.25)
Q3=columns.quantile(0.75)
IQR=Q3-Q1
IQR
# Out:
# age          15.0
# duration    217.0
# campaign      2.0
# dtype: float64

# %%
Upper_Limit=(1.5*IQR)+Q3
Lower_Limit=Q1-(1.5*IQR)

# %%
df[['age','duration','campaign']]=columns[(columns>Lower_Limit) & (columns<Upper_Limit)]

# %%
df.plot(kind='box',subplots=True,layout=(2,5), figsize=(20,10))
plt.show()

# %%
corr=df[num_col].corr()
corr
# Out:
#                      age  duration  campaign     pdays  previous  \
# age             1.000000  0.003955  0.007492  0.004496 -0.020461
# duration        0.003955  1.000000 -0.041722 -0.077167  0.052122
# campaign        0.007492 -0.041722  1.000000  0.044199 -0.060133
# pdays           0.004496 -0.077167  0.044199  1.000000 -0.587508
# previous       -0.020461  0.052122 -0.060133 -0.587508  1.000000
# emp.var.rate    0.069034 -0.061054  0.100099  0.271063 -0.420587
# cons.price.idx  0.035786 -0.005518  0.075612  0.078920 -0.203197
# cons.conf.idx   0.104399  0.005908 -0.014756 -0.091374 -0.050929
# euribor3m       0.081970 -0.068424  0.085098  0.296946 -0.454571
# nr.employed     0.065910 -0.089292  0.093340  0.372659 -0.501411
#
#                 emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  \
# age                 0.069034        0.035786       0.104399   0.081970
# duration           -0.061054       -0.005518       0.005908  -0.068424
# ...

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df[num_col].corr(),annot=True)
# Out:
# <Axes: >

# %%
high_corr=['emp.var.rate','nr.employed','euribor3m']

# %%
df.drop(columns=high_corr,inplace=True)

# %%
df.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'housing', 'loan',
#        'contact', 'month', 'day_of_week', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'cons.price.idx', 'cons.conf.idx', 'deposit'],
#       dtype='object')

# %%
df[cat_cols]
# Out:
#                job  marital            education  default housing loan  \
# 0        housemaid  married             basic.4y       no      no   no
# 1         services  married          high.school  unknown      no   no
# 2         services  married          high.school       no     yes   no
# 3           admin.  married             basic.6y       no      no   no
# 4         services  married          high.school       no      no  yes
# ...            ...      ...                  ...      ...     ...  ...
# 41183      retired  married  professional.course       no     yes   no
# 41184  blue-collar  married  professional.course       no      no   no
# 41185      retired  married    university.degree       no     yes   no
# 41186   technician  married  professional.course       no      no   no
# 41187      retired  married  professional.course       no     yes   no
#
#          contact month day_of_week     poutcome deposit
# 0      telephone   may         mon  nonexistent      no
# ...

# %%
from sklearn.preprocessing import LabelEncoder
lb=LabelEncoder()
df[cat_cols]=df[cat_cols].apply(lb.fit_transform)

# %%
df[cat_cols]
# Out:
#        job  marital  education  default  housing  loan  contact  month  \
# 0        3        1          0        0        0     0        1      6
# 1        7        1          3        1        0     0        1      6
# 2        7        1          3        0        2     0        1      6
# 3        0        1          1        0        0     0        1      6
# 4        7        1          3        0        0     2        1      6
# ...    ...      ...        ...      ...      ...   ...      ...    ...
# 41183    5        1          5        0        2     0        0      7
# 41184    1        1          5        0        0     0        0      7
# 41185    5        1          6        0        2     0        0      7
# 41186    9        1          5        0        0     0        0      7
# 41187    5        1          5        0        2     0        0      7
#
#        day_of_week  poutcome  deposit
# 0                1         1        0
# ...

# %%
df.head()
# Out:
#     age  job  marital  education  default  housing  loan  contact  month  \
# 0  56.0    3        1          0        0        0     0        1      6
# 1  57.0    7        1          3        1        0     0        1      6
# 2  37.0    7        1          3        0        2     0        1      6
# 3  40.0    0        1          1        0        0     0        1      6
# 4  56.0    7        1          3        0        0     2        1      6
#
#    day_of_week  duration  campaign  pdays  previous  poutcome  cons.price.idx  \
# 0            1     261.0       1.0    999         0         1          93.994
# 1            1     149.0       1.0    999         0         1          93.994
# 2            1     226.0       1.0    999         0         1          93.994
# 3            1     151.0       1.0    999         0         1          93.994
# 4            1     307.0       1.0    999         0         1          93.994
#
#    cons.conf.idx  deposit
# 0          -36.4        0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 41176 entries, 0 to 41187
# Data columns (total 18 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             40708 non-null  float64
#  1   job             41176 non-null  int32
#  2   marital         41176 non-null  int32
#  3   education       41176 non-null  int32
#  4   default         41176 non-null  int32
#  5   housing         41176 non-null  int32
#  6   loan            41176 non-null  int32
#  7   contact         41176 non-null  int32
#  8   month           41176 non-null  int32
#  9   day_of_week     41176 non-null  int32
#  10  duration        38213 non-null  float64
#  11  campaign        37791 non-null  float64
#  12  pdays           41176 non-null  int64
#  13  previous        41176 non-null  int64
#  14  poutcome        41176 non-null  int32
#  15  cons.price.idx  41176 non-null  float64
#  16  cons.conf.idx   41176 non-null  float64
# ...

# %%
x=df.drop('deposit',axis=1)
x.shape
# Out:
# (41176, 17)

# %%
y=df['deposit']
y.shape
# Out:
# (41176,)

# %% [markdown]
# # Model Building

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix,classification_report,accuracy_score

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
model=DecisionTreeClassifier(criterion='gini', max_depth=5, min_samples_split=15)
model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=5, min_samples_split=15)

# %%
y_pred=model.predict(x_test)

# %%
result=pd.DataFrame({'Actual_Value':y_test,'Predicted_Vale':y_pred})
result
# Out:
#        Actual_Value  Predicted_Vale
# 36264             1               1
# 32672             0               0
# 40872             1               0
# 32907             0               0
# 16464             0               0
# ...             ...             ...
# 19004             0               0
# 34252             0               0
# 13575             0               0
# 1872              0               0
# 12339             0               0
#
# [8236 rows x 2 columns]

# %%
train_score=model.score(x_train,y_train)
test_score=model.score(x_test,y_test)
print("Training Score: ",train_score)
print("\n\nTesting Score: ",test_score)
# Out:
# Training Score:  0.9107771706132362
#
#
# Testing Score:  0.90165128703254

# %%
print("Accuracy Score: ",accuracy_score(y_test,y_pred))
# Out:
# Accuracy Score:  0.90165128703254

# %%
print("Confusion Matrix: \n",confusion_matrix(y_test,y_pred))
# Out:
# Confusion Matrix:
#  [[6973  292]
#  [ 518  453]]

# %%
print("Classification Report: \n",classification_report(y_test,y_pred))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.96      0.95      7265
#            1       0.61      0.47      0.53       971
#
#     accuracy                           0.90      8236
#    macro avg       0.77      0.71      0.74      8236
# weighted avg       0.89      0.90      0.90      8236

# %%
from sklearn.tree import plot_tree

# %%
plt.figure(figsize=(10,10))
plot_tree(model,feature_names=x_train.columns,class_names=['no', 'yes'],filled=True,rounded=True,fontsize=2)
plt.show()

# %%
model1=DecisionTreeClassifier(criterion='entropy',max_depth=4,min_samples_split=15)
model1.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=4, min_samples_split=15)

# %%
y_pred1=model1.predict(x_test)

# %%
result=pd.DataFrame({'Actual_Value':y_test,'Predicted_Vale':y_pred1})
result
# Out:
#        Actual_Value  Predicted_Vale
# 36264             1               1
# 32672             0               0
# 40872             1               0
# 32907             0               0
# 16464             0               0
# ...             ...             ...
# 19004             0               0
# 34252             0               0
# 13575             0               0
# 1872              0               0
# 12339             0               0
#
# [8236 rows x 2 columns]

# %%
train_score=model1.score(x_train,y_train)
test_score=model1.score(x_test,y_test)
print("Training Score: ",train_score)
print("\n\nTesting Score: ",test_score)
# Out:
# Training Score:  0.9069520340012144
#
#
# Testing Score:  0.9021369596891695

# %%
print("Accuracy Score: ",accuracy_score(y_test,y_pred1))
# Out:
# Accuracy Score:  0.9021369596891695

# %%
print("Confusion Matrix: \n",confusion_matrix(y_test,y_pred1))
# Out:
# Confusion Matrix:
#  [[7053  212]
#  [ 594  377]]

# %%
print("Classification Report: \n",classification_report(y_test,y_pred1))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.92      0.97      0.95      7265
#            1       0.64      0.39      0.48       971
#
#     accuracy                           0.90      8236
#    macro avg       0.78      0.68      0.71      8236
# weighted avg       0.89      0.90      0.89      8236

# %%
plt.figure(figsize=(150,80))
plot_tree(model1,class_names=['no', 'yes'],filled=True,fontsize=50)
plt.show()
